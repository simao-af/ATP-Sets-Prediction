# %% [markdown]
# #### Imports

# %%
import datetime
import numpy as np
import pandas as pd
import random
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns

## for plotting
import matplotlib.pyplot as plt
import seaborn as sns

## for machine learning
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

## for statistical tests
import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm
 
## for explainer
from lime import lime_tabular
    
## plot style and warnings    
plt.style.use('ggplot')
from IPython.display import display # Allows the use of display() for DataFrames
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Abertura da Base de Dados

# %%
df = pd.read_csv('atpplayers.csv', sep=',')

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ### Informaçãoes sobre a base de dados

# %%
df.head(6)
# Out:
#        PlayerName              Born  Height  \
# 0  Novak Djokovic  Belgrade, Serbia   188.0
# 1  Novak Djokovic  Belgrade, Serbia   188.0
# 2  Novak Djokovic  Belgrade, Serbia   188.0
# 3  Novak Djokovic  Belgrade, Serbia   188.0
# 4  Novak Djokovic  Belgrade, Serbia   188.0
# 5  Novak Djokovic  Belgrade, Serbia   188.0
#
#                                 Hand  \
# 0  Right-Handed, Two-Handed Backhand
# 1  Right-Handed, Two-Handed Backhand
# 2  Right-Handed, Two-Handed Backhand
# 3  Right-Handed, Two-Handed Backhand
# 4  Right-Handed, Two-Handed Backhand
# 5  Right-Handed, Two-Handed Backhand
#
#                                           LinkPlayer        Tournament  \
# 0  https://www.atptour.com/en/players/novak-djoko...             Dubai
# 1  https://www.atptour.com/en/players/novak-djoko...  Davis Cup Finals
# 2  https://www.atptour.com/en/players/novak-djoko...           US Open
# 3  https://www.atptour.com/en/players/novak-djoko...           US Open
# 4  https://www.atptour.com/en/players/novak-djoko...           US Open
# 5  https://www.atptour.com/en/players/novak-djoko...  Davis Cup Finals
#
#                Location                     Date Ground        Prize  \
# 0         Dubai, U.A.E.  2022.02.21 - 2022.02.26   Hard   $2,794,840
# 1         Madrid, Spain  2021.11.22 - 2021.12.05   Hard          NaN
# 2  New York, NY, U.S.A.  2021.08.30 - 2021.09.12   Hard  $27,200,000
# 3  New York, NY, U.S.A.  2021.08.30 - 2021.09.12   Hard  $27,200,000
# 4  New York, NY, U.S.A.  2021.08.30 - 2021.09.12   Hard  $27,200,000
# 5         Madrid, Spain  2021.11.22 - 2021.12.05   Hard          NaN
#
#       GameRound GameRank             Oponent WL           Score
# 0   Round of 16       26     Karen Khachanov  W           63 76
# 1   Round Robin       51  Jan-Lennard Struff  W           62 64
# 2  Round of 128      145         Holger Rune  W   61 67,  62 61
# 3   Round of 64      121   Tallon Griekspoor  W        62 63 62
# 4   Semi-Finals        4    Alexander Zverev  W  46 62 64 46 62
# 5   Semi-Finals       30         Marin Cilic  W           64 62

# %%
df.shape
# Out:
# (1308835, 15)

# %%
df.columns
# Out:
# Index(['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer', 'Tournament',
#        'Location', 'Date', 'Ground', 'Prize', 'GameRound', 'GameRank',
#        'Oponent', 'WL', 'Score'],
#       dtype='object')

# %% [markdown]
# ### Transformações à base de dados

# %% [markdown]
# Foram apagadas as variáveis que não vão ser utilizadas.

# %%
df = df.drop(['Hand', 'LinkPlayer'], axis=1)

# %%
df = df.drop(['Height'], axis=1)

# %%
df = df.drop(['Born'], axis=1)

# %%
df.isna().sum()
# Out:
# PlayerName        0
# Tournament        0
# Location          0
# Date              0
# Ground          191
# Prize         19136
# GameRound         0
# GameRank      19236
# Oponent           7
# WL            19257
# Score         19400
# dtype: int64

# %%
df.dropna(subset=['Score'], inplace=True)

# %%
df.isna().sum()
# Out:
# PlayerName        0
# Tournament        0
# Location          0
# Date              0
# Ground          191
# Prize         19109
# GameRound         0
# GameRank          0
# Oponent           7
# WL                0
# Score             0
# dtype: int64

# %%
df = df.drop(['Prize'], axis=1)

# %%
df.head(6)
# Out:
#        PlayerName        Tournament              Location  \
# 0  Novak Djokovic             Dubai         Dubai, U.A.E.
# 1  Novak Djokovic  Davis Cup Finals         Madrid, Spain
# 2  Novak Djokovic           US Open  New York, NY, U.S.A.
# 3  Novak Djokovic           US Open  New York, NY, U.S.A.
# 4  Novak Djokovic           US Open  New York, NY, U.S.A.
# 5  Novak Djokovic  Davis Cup Finals         Madrid, Spain
#
#                       Date Ground     GameRound GameRank             Oponent  \
# 0  2022.02.21 - 2022.02.26   Hard   Round of 16       26     Karen Khachanov
# 1  2021.11.22 - 2021.12.05   Hard   Round Robin       51  Jan-Lennard Struff
# 2  2021.08.30 - 2021.09.12   Hard  Round of 128      145         Holger Rune
# 3  2021.08.30 - 2021.09.12   Hard   Round of 64      121   Tallon Griekspoor
# 4  2021.08.30 - 2021.09.12   Hard   Semi-Finals        4    Alexander Zverev
# 5  2021.11.22 - 2021.12.05   Hard   Semi-Finals       30         Marin Cilic
#
#   WL           Score
# 0  W           63 76
# 1  W           62 64
# 2  W   61 67,  62 61
# 3  W        62 63 62
# 4  W  46 62 64 46 62
# 5  W           64 62

# %% [markdown]
# Criação de uma base de dados espelhada onde o opponent vai para o playername e vice-versa.

# %%
df_mirror = df.copy()
df_mirror['Oponent'], df_mirror['PlayerName'] = df_mirror['PlayerName'], df_mirror['Oponent']

df_concat = pd.concat([df, df_mirror], axis=0, ignore_index=True)
counted = df_concat.groupby(['Date', 'GameRound', 'Oponent', 'PlayerName']).size().reset_index(name='count')

matching_rows = counted[counted['count'] > 1]
print(len(matching_rows))

unmatched_rows = df[~df.set_index(['Date', 'GameRound', 'Oponent', 'PlayerName']).index.isin(matching_rows.set_index(['Date', 'GameRound', 'Oponent', 'PlayerName']).index)]
unmatched_list = unmatched_rows.to_dict('records')

my_list = list(unmatched_list)
# Out:
# 1211700

# %%
print(df.shape[0] - len(matching_rows))
# Out:
# 77735

# %%
df_nao_espelhados=pd.DataFrame(my_list)
print(len(df_nao_espelhados))
# Out:
# 76119

# %%
len(df_nao_espelhados[df_nao_espelhados['WL'] == 'W'])
# Out:
# 54312

# %%
df_nao_espelhados = df_nao_espelhados[df_nao_espelhados['WL'] == 'W']
len(df_nao_espelhados)
# Out:
# 54312

# %%
matched_df = pd.merge(df, matching_rows, on=['Date', 'GameRound', 'Oponent', 'PlayerName'], how='inner')
matched_df.shape
# Out:
# (1213316, 11)

# %%
matched_df = matched_df.drop('count', axis=1)
matched_df.head(6)
# Out:
#        PlayerName        Tournament              Location  \
# 0  Novak Djokovic             Dubai         Dubai, U.A.E.
# 1  Novak Djokovic  Davis Cup Finals         Madrid, Spain
# 2  Novak Djokovic           US Open  New York, NY, U.S.A.
# 3  Novak Djokovic           US Open  New York, NY, U.S.A.
# 4  Novak Djokovic           US Open  New York, NY, U.S.A.
# 5  Novak Djokovic  Davis Cup Finals         Madrid, Spain
#
#                       Date Ground     GameRound GameRank             Oponent  \
# 0  2022.02.21 - 2022.02.26   Hard   Round of 16       26     Karen Khachanov
# 1  2021.11.22 - 2021.12.05   Hard   Round Robin       51  Jan-Lennard Struff
# 2  2021.08.30 - 2021.09.12   Hard  Round of 128      145         Holger Rune
# 3  2021.08.30 - 2021.09.12   Hard   Round of 64      121   Tallon Griekspoor
# 4  2021.08.30 - 2021.09.12   Hard   Semi-Finals        4    Alexander Zverev
# 5  2021.11.22 - 2021.12.05   Hard   Semi-Finals       30         Marin Cilic
#
#   WL           Score
# 0  W           63 76
# 1  W           62 64
# 2  W   61 67,  62 61
# 3  W        62 63 62
# 4  W  46 62 64 46 62
# 5  W           64 62

# %%
matched_df = matched_df[matched_df['WL'] == 'W']
len(matched_df)
# Out:
# 606955

# %%
new_df = pd.concat([df_nao_espelhados, matched_df], axis=0, ignore_index=True)
len(new_df)
# Out:
# 661267

# %%
new_df.head(6)
# Out:
#        PlayerName               Tournament               Location  \
# 0  Novak Djokovic  ATP Masters 1000 Canada        Toronto, Canada
# 1  Novak Djokovic            Roland Garros          Paris, France
# 2  Novak Djokovic   ATP Masters 1000 Miami      Miami, FL, U.S.A.
# 3  Novak Djokovic               ATP Finals  London, Great Britain
# 4  Novak Djokovic                     Doha            Doha, Qatar
# 5  Novak Djokovic   ATP Masters 1000 Paris          Paris, France
#
#                       Date Ground       GameRound GameRank        Oponent WL  \
# 0  2016.07.25 - 2016.07.31   Hard  Quarter-Finals        8  Tomas Berdych  W
# 1  2016.05.23 - 2016.06.05   Clay  Quarter-Finals        8  Tomas Berdych  W
# 2  2016.03.21 - 2016.04.03   Hard  Quarter-Finals        7  Tomas Berdych  W
# 3  2015.11.16 - 2015.11.22   Hard     Round Robin        6  Tomas Berdych  W
# 4  2016.01.04 - 2016.01.10   Hard     Semi-Finals        6  Tomas Berdych  W
# 5  2015.11.02 - 2015.11.08   Hard  Quarter-Finals        5  Tomas Berdych  W
#
#       Score
# 0   76,  64
# 1  63 75 63
# 2     63 63
# 3     63 75
# 4     63 76
# 5   76,  76

# %%
new_df.loc[(new_df['PlayerName'] == "Boris Becker")]
# Out:
#           PlayerName       Tournament                Location  \
# 34917   Boris Becker  Australian Open    Melbourne, Australia
# 34918   Boris Becker      Stuttgart-1      Stuttgart, Germany
# 34919   Boris Becker          US Open    New York, NY, U.S.A.
# 34920   Boris Becker    IND V GER 1RD                 Germany
# 34921   Boris Becker    IND V GER 1RD                 Germany
# ...              ...              ...                     ...
# 571114  Boris Becker          Wembley        Wembley, England
# 571115  Boris Becker           Vienna         Vienna, Austria
# 571116  Boris Becker        Wimbledon         London, England
# 571117  Boris Becker          Hamburg        Hamburg, Germany
# 571118  Boris Becker       Luxembourg  Luxembourg, Luxembourg
#
#                            Date  Ground       GameRound GameRank  \
# 34917   1990.01.15 - 1990.01.28    Hard     Round of 16       25
# 34918   1990.02.19 - 1990.02.25  Carpet  Quarter-Finals       26
# 34919   1989.08.28 - 1989.09.10    Hard     Round of 32       22
# 34920   1989.01.30 - 1989.02.12  Carpet     Round Robin      860
# 34921   1989.01.30 - 1989.02.12  Carpet     Round Robin      412
# ...                         ...     ...             ...      ...
# 571114  1984.11.05 - 1984.11.11  Carpet     Round of 32       92
# 571115  1984.10.22 - 1984.10.28    Hard     Round of 32      145
# 571116               1984.06.25   Grass     Round of 64       52
# 571117               1984.05.07    Clay     Round of 64        -
# 571118               1984.04.09  Carpet     Round of 32        -
#
#                    Oponent WL           Score
# 34917   Miloslav Mecir Sr.  W  46 67 64 61 61
# 34918   Miloslav Mecir Sr.  W           64 62
# 34919   Miloslav Mecir Sr.  W     64 36 64 63
# 34920      Abdul Kahar Mim  W        60 61 61
# 34921        Tintus Wibowo  W           62 75
# ...                    ... ..             ...
# 571114      Emilio Sanchez  W           64 61
# 571115       Karel Novacek  W        64 67 61
# 571116        Nduka Odizor  W  63 64 42 (RET)
# 571117        Sergio Casal  W        63 67 61
# 571118   Florin Segarceanu  W        67 63 62
#
# [716 rows x 10 columns]

# %%
new_df.loc[(new_df['PlayerName'] == "Boris Becker") & (new_df["Oponent"]=="John McEnroe")]
# Out:
#           PlayerName              Tournament                       Location  \
# 570706  Boris Becker  ATP Masters 1000 Paris                  Paris, France
# 570743  Boris Becker               Rotterdam         Rotterdam, Netherlands
# 570873  Boris Becker                 Masters                     NY, U.S.A.
# 570884  Boris Becker                   Paris                  Paris, France
# 570928  Boris Becker                   Milan                   Milan, Italy
# 570949  Boris Becker            Indianapolis       Indianapolis, IN, U.S.A.
# 571005  Boris Becker          GER V USA WGPO                         U.S.A.
# 571057  Boris Becker       Stratton Mountain  Stratton Mountain, VT, U.S.A.
#
#                            Date  Ground    GameRound GameRank       Oponent  \
# 570706  1992.11.02 - 1992.11.08  Carpet  Round of 32       22  John McEnroe
# 570743  1992.02.24 - 1992.03.01  Carpet  Semi-Finals       30  John McEnroe
# 570873  1989.11.27 - 1989.12.03  Carpet  Semi-Finals        4  John McEnroe
# 570884  1989.10.30 - 1989.11.05  Carpet  Semi-Finals        4  John McEnroe
# 570928  1989.02.13 - 1989.02.19  Carpet  Semi-Finals        9  John McEnroe
# 570949  1988.08.01 - 1988.08.07    Hard       Finals       17  John McEnroe
# 571005  1987.07.20 - 1987.07.26  Carpet  Round Robin        9  John McEnroe
# 571057  1986.08.04 - 1986.08.10    Hard  Semi-Finals        7  John McEnroe
#
#        WL              Score
# 570706  W              64 64
# 570743  W              62 76
# 570873  W              64 64
# 570884  W           76 36 63
# 570928  W              62 63
# 570949  W              64 62
# 571005  W  46 15-138-1062 62
# 571057  W           36 75 76

# %%
new_df['Score_Sets'] = new_df['Score'].apply(lambda x: x.replace(' ', '').replace(',', '').replace('-', ''))
new_df['Score_Sets'] = new_df['Score_Sets'].str.replace('(RET)', '').str.replace('(DEF)', '')
new_df['Score_Sets'] = new_df['Score_Sets'].str.replace(r'\(.*\)', '')
import re
new_df["Score_Sets"] = new_df["Score_Sets"].apply(lambda x: re.sub(r"(\d{2})", r"\1-", x)[:-1])

# %%
def count_sets(row):
    sets = row['Score_Sets']
    if '-' not in sets:
        return 1
    else:
        return sets.count('-') + 1

new_df['Sets'] = new_df.apply(count_sets, axis=1)

# %%
new_df['Sets'].value_counts()
# Out:
# 2    435205
# 3    202389
# 1      9850
# 4      8683
# 5      4872
# 6       267
# 7         1
# Name: Sets, dtype: int64

# %%
new_df.loc[(new_df['Sets'] == 7) | (new_df['Sets'] == 6)]
# Out:
#               PlayerName              Tournament               Location  \
# 433      Grigor Dimitrov           Roland Garros          Paris, France
# 29712      Wesley Moodie  RSA v. GER EAGI 2nd RD    Doornfontein, South
# 33537         John James                Adelaide    Adelaide, Australia
# 35115   Leonardo Lavalle           GER V MEX 1RD                 Mexico
# 35475   Jean-Noel Grinda               Wimbledon  London, Great Britain
# ...                  ...                     ...                    ...
# 614892    Harold Solomon           Roland Garros          Paris, France
# 614893    Harold Solomon           Roland Garros          Paris, France
# 615121      Peter Doohan               Wimbledon        London, England
# 630858    Andrey Golubev   KAZ vs. BEL WG 1st RD             Kazakhstan
# 631827       Andy Murray           Roland Garros          Paris, France
#
#                            Date Ground     GameRound GameRank  \
# 433     2018.05.28 - 2018.06.10   Clay   Round of 64       57
# 29712   2005.02.28 - 2005.03.06   Hard   Round Robin       16
# 33537   1968.11.25 - 1968.12.01  Grass   Round of 64        -
# 35115   1986.03.03 - 1986.03.16   Clay   Round Robin       50
# 35475   1954.06.21 - 1954.07.02  Grass  Round of 128        -
# ...                         ...    ...           ...      ...
# 614892  1972.05.22 - 1972.06.04   Clay   Round of 16        -
# 614893  1972.05.22 - 1972.06.04   Clay   Round of 16        -
# 615121  1987.06.22 - 1987.07.05  Grass   Round of 32      166
# 630858  2014.01.27 - 2014.02.02   Hard   Round Robin      113
# 631827  2014.05.26 - 2014.06.08   Clay   Round of 32       24
#
#                       Oponent WL                Score         Score_Sets  Sets
# 433           Jared Donaldson  W   67,  64 46 64 10-8    67-64-46-64-10-     6
# 29712              Tommy Haas  W   67,  62 46 63 10-8    67-62-46-63-10-     6
# 33537            Jeff Simpson  W      46 75 61 8-1063    46-75-61-81-06-     6
# 35115        Michael Westphal  W      8-1036 63 64 63    81-03-66-36-46-     6
# 35475             Guy Jackson  W      64 64 8-1036 75    64-64-81-03-67-     6
# ...                       ... ..                  ...                ...   ...
# 614892        Guillermo Vilas  W      36 8-1062 64 64    36-81-06-26-46-     6
# 614893        Guillermo Vilas  W      36 8-1062 64 64    36-81-06-26-46-     6
# 615121            Leif Shiras  W    67 46 63 64 12-10  67-46-63-64-12-10     6
# 630858           David Goffin  W  76,  36 46 62 12-10  76-36-46-62-12-10     6
# 631827  Philipp Kohlschreiber  W    36 63 63 46 12-10  36-63-63-46-12-10     6
#
# [268 rows x 12 columns]

# %%
new_df['Sets'] = new_df['Sets'].replace([6, 7], 5)

# %%
new_df['Sets'].value_counts()
# Out:
# 2    435205
# 3    202389
# 1      9850
# 4      8683
# 5      5140
# Name: Sets, dtype: int64

# %%
new_df = new_df[~new_df['Sets'].isin([1])]

# %%
new_df['Score'].unique()
# Out:
# array(['76,  64', '63 75 63', '63 63', ..., '16 63 61 46 61',
#        '46 62 60 75', '63 06 10-7'], dtype=object)

# %%
new_df[['Start_Date', 'End_Date']] = new_df['Date'].str.split(' - ', expand=True) #Criação de 2 novas colunas

# %%
new_df['Start_Date'] = pd.to_datetime(new_df['Start_Date'], format='%Y.%m.%d')
new_df['End_Date'] = pd.to_datetime(new_df['End_Date'], format='%Y.%m.%d')

# %%
rafael_games = new_df[(new_df['PlayerName'] == 'Rafael Nadal') | (new_df['Oponent'] == 'Rafael Nadal')]

filtered_games = rafael_games[rafael_games['Start_Date'] < '2017-10-09']

filtered_games = filtered_games.sort_values('Date', ascending=False)
filtered_games.head(5)
# Out:
#          PlayerName Tournament        Location                     Date  \
# 55865  Rafael Nadal    Beijing  Beijing, China  2017.10.02 - 2017.10.08
# 55866  Rafael Nadal    Beijing  Beijing, China  2017.10.02 - 2017.10.08
# 55867  Rafael Nadal    Beijing  Beijing, China  2017.10.02 - 2017.10.08
# 55868  Rafael Nadal    Beijing  Beijing, China  2017.10.02 - 2017.10.08
# 55869  Rafael Nadal    Beijing  Beijing, China  2017.10.02 - 2017.10.08
#
#       Ground       GameRound GameRank          Oponent WL       Score  \
# 55865   Hard          Finals       19     Nick Kyrgios  W       62 61
# 55866   Hard  Quarter-Finals       17       John Isner  W       64 76
# 55867   Hard     Semi-Finals        8  Grigor Dimitrov  W    63 46 61
# 55868   Hard     Round of 16       42  Karen Khachanov  W       63 63
# 55869   Hard     Round of 32       23    Lucas Pouille  W  46 76,  75
#
#       Score_Sets  Sets Start_Date   End_Date
# 55865      62-61     2 2017-10-02 2017-10-08
# 55866      64-76     2 2017-10-02 2017-10-08
# 55867   63-46-61     3 2017-10-02 2017-10-08
# 55868      63-63     2 2017-10-02 2017-10-08
# 55869   46-76-75     3 2017-10-02 2017-10-08

# %%
print(filtered_games)
# Out:
#               PlayerName Tournament         Location                     Date  \
# 55865       Rafael Nadal    Beijing   Beijing, China  2017.10.02 - 2017.10.08
#  '2003.05.12 - 2003.05.18' '2003.04.28 - 2003.05.04'
#  '2003.04.21 - 2003.04.27' '2003.04.14 - 2003.04.20'
#  '2003.03.24 - 2003.03.30' '2003.03.17 - 2003.03.30'
#  '2003.03.03 - 2003.03.09' '2003.02.24 - 2003.03.02'
#  '2003.02.03 - 2003.02.09' '2003.01.27 - 2003.02.02'
#  '2002.11.25 - 2002.12.01' '2002.11.18 - 2002.11.24'
#  '2002.10.07 - 2002.10.13' '2002.09.30 - 2002.10.06'
#  '2002.09.23 - 2002.09.29' '2002.09.16 - 2002.09.22'
#  '2002.08.26 - 2002.09.01' '2002.08.19 - 2002.09.01'
#  '2002.08.12 - 2002.08.18' '2002.07.22 - 2002.07.28'
#  '2002.07.08 - 2002.07.14' '2002.04.29 - 2002.05.05'
#  '2001.09.17 - 2001.09.23' '2001.09.10 - 2001.09.16']

# %%
new_df['Year'] = new_df['Start_Date'].dt.year

# %%
new_df[((new_df['PlayerName'] == 'Rafael Nadal') | (new_df['Oponent'] == 'Rafael Nadal')) & (new_df['Year'] == 2017)]
# Out:
#            PlayerName                   Tournament                Location  \
# 74       Rafael Nadal    ATP Masters 1000 Shanghai         Shanghai, China
# 75       Rafael Nadal              Australian Open    Melbourne, Australia
# 55860    Rafael Nadal       ATP Masters 1000 Paris           Paris, France
# 55861    Rafael Nadal       ATP Masters 1000 Paris           Paris, France
# 55862    Rafael Nadal    ATP Masters 1000 Shanghai         Shanghai, China
# ...               ...                          ...                     ...
# 77515    David Goffin             Nitto ATP Finals   London, Great Britain
# 87184    Nick Kyrgios  ATP Masters 1000 Cincinnati  Cincinnati, OH, U.S.A.
# 89871     Sam Querrey                     Acapulco        Acapulco, Mexico
# 109261   Milos Raonic                     Brisbane     Brisbane, Australia
# 251889  Gilles Muller                    Wimbledon   London, Great Britain
#
#                            Date Ground       GameRound GameRank  \
# 74      2017.10.09 - 2017.10.15   Hard     Round of 32       56
# 75      2017.01.16 - 2017.01.29   Hard     Round of 64       36
# 55860   2017.10.30 - 2017.11.05   Hard     Round of 16       36
# 55861   2017.10.30 - 2017.11.05   Hard     Round of 32       55
# 55862   2017.10.09 - 2017.10.15   Hard  Quarter-Finals        9
# ...                         ...    ...             ...      ...
# 77515   2017.11.13 - 2017.11.19   Hard     Round Robin        1
# 87184   2017.08.14 - 2017.08.20   Hard  Quarter-Finals        2
# 89871   2017.02.27 - 2017.03.04   Hard          Finals        6
# 109261  2017.01.02 - 2017.01.08   Hard  Quarter-Finals        9
# 251889  2017.07.03 - 2017.07.16  Grass     Round of 16        2
#
#                  Oponent WL              Score         Score_Sets  Sets  \
# 74       Jared Donaldson  W              62 61              62-61     2
# 75      Marcos Baghdatis  W           63 61 63           63-61-63     3
# 55860       Pablo Cuevas  W         63 67,  63           63-67-63     3
# 55861        Hyeon Chung  W              75 63              75-63     2
# 55862    Grigor Dimitrov  W         64 67,  63           64-67-63     3
# ...                  ... ..                ...                ...   ...
# 77515       Rafael Nadal  W       76,  67,  64           76-67-64     3
# 87184       Rafael Nadal  W              62 75              62-75     2
# 89871       Rafael Nadal  W              63 76              63-76     2
# 109261      Rafael Nadal  W           46 63 64           46-63-64     3
# 251889      Rafael Nadal  W  63 64 36 46 15-13  63-64-36-46-15-13     5
#
#        Start_Date   End_Date  Year
# 74     2017-10-09 2017-10-15  2017
# 75     2017-01-16 2017-01-29  2017
# 55860  2017-10-30 2017-11-05  2017
# 55861  2017-10-30 2017-11-05  2017
# 55862  2017-10-09 2017-10-15  2017
# ...           ...        ...   ...
# 77515  2017-11-13 2017-11-19  2017
# 87184  2017-08-14 2017-08-20  2017
# 89871  2017-02-27 2017-03-04  2017
# 109261 2017-01-02 2017-01-08  2017
# 251889 2017-07-03 2017-07-16  2017
#
# [79 rows x 15 columns]

# %%
len(new_df)
# Out:
# 651417

# %%
sorted_games = new_df.sort_values('Start_Date', ascending=False)
grouped_games = sorted_games.groupby(['PlayerName', 'Oponent'])

recent_perf_median = grouped_games['Sets'].rolling(window=5, min_periods=1).median().reset_index(level=0, drop=True)
recent_perf_median = recent_perf_median.groupby(level=0).apply(lambda x: np.clip(round(x.median()), 2, 3))

default_recent_perf = dict(zip(new_df['PlayerName'].unique(), new_df['Sets']))

new_df['PlayerName_RecentPerformance'] = new_df['PlayerName'].map(recent_perf_median).fillna(default_recent_perf).values
new_df['Oponent_RecentPerformance'] = new_df['Oponent'].map(recent_perf_median).fillna(default_recent_perf).values

# %%
new_df['PlayerName_RecentPerformance'].value_counts()
# Out:
# 2.0    624597
# 3.0     26406
# Name: PlayerName_RecentPerformance, dtype: int64

# %%
new_df['Oponent_RecentPerformance'].value_counts()
# Out:
# 2.0    635832
# 3.0     15579
# Name: Oponent_RecentPerformance, dtype: int64

# %%
sorted_games = new_df.sort_values('Start_Date', ascending=False)

grouped_games = sorted_games.groupby(['PlayerName', 'Oponent'])

recent_perf_mean = grouped_games['Sets'].rolling(window=5, min_periods=1).mean().reset_index(level=0, drop=True)
recent_perf_mean = recent_perf_mean.groupby(level=0).apply(lambda x: np.clip(round(x.mean()), 2, 3))

default_recent_perf = dict(zip(new_df['PlayerName'].unique(), new_df['Sets']))

new_df['PlayerName_RecentPerformance2'] = new_df['PlayerName'].map(recent_perf_mean).fillna(default_recent_perf).values
new_df['Oponent_RecentPerformance2'] = new_df['Oponent'].map(recent_perf_mean).fillna(default_recent_perf).values

# %%
new_df['PlayerName_RecentPerformance2'].value_counts()
# Out:
# 2.0    505891
# 3.0    145112
# Name: PlayerName_RecentPerformance2, dtype: int64

# %%
new_df['Oponent_RecentPerformance2'].value_counts()
# Out:
# 2.0    542884
# 3.0    108527
# Name: Oponent_RecentPerformance2, dtype: int64

# %%
new_df.head(6)
# Out:
#        PlayerName               Tournament               Location  \
# 0  Novak Djokovic  ATP Masters 1000 Canada        Toronto, Canada
# 1  Novak Djokovic            Roland Garros          Paris, France
# 2  Novak Djokovic   ATP Masters 1000 Miami      Miami, FL, U.S.A.
# 3  Novak Djokovic               ATP Finals  London, Great Britain
# 4  Novak Djokovic                     Doha            Doha, Qatar
# 5  Novak Djokovic   ATP Masters 1000 Paris          Paris, France
#
#                       Date Ground       GameRound GameRank        Oponent WL  \
# 0  2016.07.25 - 2016.07.31   Hard  Quarter-Finals        8  Tomas Berdych  W
# 1  2016.05.23 - 2016.06.05   Clay  Quarter-Finals        8  Tomas Berdych  W
# 2  2016.03.21 - 2016.04.03   Hard  Quarter-Finals        7  Tomas Berdych  W
# 3  2015.11.16 - 2015.11.22   Hard     Round Robin        6  Tomas Berdych  W
# 4  2016.01.04 - 2016.01.10   Hard     Semi-Finals        6  Tomas Berdych  W
# 5  2015.11.02 - 2015.11.08   Hard  Quarter-Finals        5  Tomas Berdych  W
#
#       Score Score_Sets  Sets Start_Date   End_Date  Year  \
# 0   76,  64      76-64     2 2016-07-25 2016-07-31  2016
# 1  63 75 63   63-75-63     3 2016-05-23 2016-06-05  2016
# 2     63 63      63-63     2 2016-03-21 2016-04-03  2016
# 3     63 75      63-75     2 2015-11-16 2015-11-22  2015
# 4     63 76      63-76     2 2016-01-04 2016-01-10  2016
# 5   76,  76      76-76     2 2015-11-02 2015-11-08  2015
#
#    PlayerName_RecentPerformance  Oponent_RecentPerformance  \
# 0                           3.0                        2.0
# 1                           3.0                        2.0
# 2                           3.0                        2.0
# 3                           3.0                        2.0
# 4                           3.0                        2.0
# 5                           3.0                        2.0
#
#    PlayerName_RecentPerformance2  Oponent_RecentPerformance2
# 0                            3.0                         3.0
# 1                            3.0                         3.0
# 2                            3.0                         3.0
# 3                            3.0                         3.0
# 4                            3.0                         3.0
# 5                            3.0                         3.0

# %%
new_df['PlayerName_RecentPerformance'].value_counts()
# Out:
# 2.0    624597
# 3.0     26406
# Name: PlayerName_RecentPerformance, dtype: int64

# %%
new_df['Oponent_RecentPerformance'].value_counts()
# Out:
# 2.0    635832
# 3.0     15579
# Name: Oponent_RecentPerformance, dtype: int64

# %%
new_df.head(6)
# Out:
#        PlayerName               Tournament               Location  \
# 0  Novak Djokovic  ATP Masters 1000 Canada        Toronto, Canada
# 1  Novak Djokovic            Roland Garros          Paris, France
# 2  Novak Djokovic   ATP Masters 1000 Miami      Miami, FL, U.S.A.
# 3  Novak Djokovic               ATP Finals  London, Great Britain
# 4  Novak Djokovic                     Doha            Doha, Qatar
# 5  Novak Djokovic   ATP Masters 1000 Paris          Paris, France
#
#                       Date Ground       GameRound GameRank        Oponent WL  \
# 0  2016.07.25 - 2016.07.31   Hard  Quarter-Finals        8  Tomas Berdych  W
# 1  2016.05.23 - 2016.06.05   Clay  Quarter-Finals        8  Tomas Berdych  W
# 2  2016.03.21 - 2016.04.03   Hard  Quarter-Finals        7  Tomas Berdych  W
# 3  2015.11.16 - 2015.11.22   Hard     Round Robin        6  Tomas Berdych  W
# 4  2016.01.04 - 2016.01.10   Hard     Semi-Finals        6  Tomas Berdych  W
# 5  2015.11.02 - 2015.11.08   Hard  Quarter-Finals        5  Tomas Berdych  W
#
#       Score Score_Sets  Sets Start_Date   End_Date  Year  \
# 0   76,  64      76-64     2 2016-07-25 2016-07-31  2016
# 1  63 75 63   63-75-63     3 2016-05-23 2016-06-05  2016
# 2     63 63      63-63     2 2016-03-21 2016-04-03  2016
# 3     63 75      63-75     2 2015-11-16 2015-11-22  2015
# 4     63 76      63-76     2 2016-01-04 2016-01-10  2016
# 5   76,  76      76-76     2 2015-11-02 2015-11-08  2015
#
#    PlayerName_RecentPerformance  Oponent_RecentPerformance  \
# 0                           3.0                        2.0
# 1                           3.0                        2.0
# 2                           3.0                        2.0
# 3                           3.0                        2.0
# 4                           3.0                        2.0
# 5                           3.0                        2.0
#
#    PlayerName_RecentPerformance2  Oponent_RecentPerformance2
# 0                            3.0                         3.0
# 1                            3.0                         3.0
# 2                            3.0                         3.0
# 3                            3.0                         3.0
# 4                            3.0                         3.0
# 5                            3.0                         3.0

# %%
sorted_df = new_df.sort_values('Start_Date')

sorted_df['PlayerName_LastTimePlayed'] = sorted_df.groupby('PlayerName')['Start_Date'].diff().dt.days
sorted_df['Oponent_LastTimePlayed'] = sorted_df.groupby('Oponent')['Start_Date'].diff().dt.days

mask = (sorted_df['Tournament'] == sorted_df.groupby('PlayerName')['Tournament'].shift(-1)) & (sorted_df['Start_Date'] == sorted_df.groupby('PlayerName')['Start_Date'].shift(-1))
sorted_df.loc[mask, 'PlayerName_LastTimePlayed'] = 1

mask = (sorted_df['Tournament'] == sorted_df.groupby('Oponent')['Tournament'].shift(-1)) & (sorted_df['Start_Date'] == sorted_df.groupby('Oponent')['Start_Date'].shift(-1))
sorted_df.loc[mask, 'Oponent_LastTimePlayed'] = 1

new_df['PlayerName_LastTimePlayed'] = sorted_df['PlayerName_LastTimePlayed']
new_df['Oponent_LastTimePlayed'] = sorted_df['Oponent_LastTimePlayed']

# %%
new_df.head(6)
# Out:
#        PlayerName               Tournament               Location  \
# 0  Novak Djokovic  ATP Masters 1000 Canada        Toronto, Canada
# 1  Novak Djokovic            Roland Garros          Paris, France
# 2  Novak Djokovic   ATP Masters 1000 Miami      Miami, FL, U.S.A.
# 3  Novak Djokovic               ATP Finals  London, Great Britain
# 4  Novak Djokovic                     Doha            Doha, Qatar
# 5  Novak Djokovic   ATP Masters 1000 Paris          Paris, France
#
#                       Date Ground       GameRound GameRank        Oponent WL  \
# 0  2016.07.25 - 2016.07.31   Hard  Quarter-Finals        8  Tomas Berdych  W
# 1  2016.05.23 - 2016.06.05   Clay  Quarter-Finals        8  Tomas Berdych  W
# 2  2016.03.21 - 2016.04.03   Hard  Quarter-Finals        7  Tomas Berdych  W
# 3  2015.11.16 - 2015.11.22   Hard     Round Robin        6  Tomas Berdych  W
# 4  2016.01.04 - 2016.01.10   Hard     Semi-Finals        6  Tomas Berdych  W
# 5  2015.11.02 - 2015.11.08   Hard  Quarter-Finals        5  Tomas Berdych  W
#
#       Score  ... Sets  Start_Date   End_Date  Year  \
# 0   76,  64  ...    2  2016-07-25 2016-07-31  2016
# 1  63 75 63  ...    3  2016-05-23 2016-06-05  2016
# 2     63 63  ...    2  2016-03-21 2016-04-03  2016
# 3     63 75  ...    2  2015-11-16 2015-11-22  2015
# 4     63 76  ...    2  2016-01-04 2016-01-10  2016
# 5   76,  76  ...    2  2015-11-02 2015-11-08  2015
#
#    PlayerName_RecentPerformance  Oponent_RecentPerformance  \
# 0                           3.0                        2.0
# 1                           3.0                        2.0
# 2                           3.0                        2.0
# 3                           3.0                        2.0
# 4                           3.0                        2.0
# 5                           3.0                        2.0
#
#    PlayerName_RecentPerformance2  Oponent_RecentPerformance2  \
# 0                            3.0                         3.0
# 1                            3.0                         3.0
# 2                            3.0                         3.0
# 3                            3.0                         3.0
# 4                            3.0                         3.0
# 5                            3.0                         3.0
#
#    PlayerName_LastTimePlayed  Oponent_LastTimePlayed
# 0                        0.0                    28.0
# 1                        0.0                    14.0
# 2                        1.0                    14.0
# 3                        1.0                     1.0
# 4                        0.0                    49.0
# 5                        0.0                    21.0
#
# [6 rows x 21 columns]

# %%
new_df[new_df['PlayerName'] == 'Rafael Nadal']
# Out:
#          PlayerName                     Tournament                  Location  \
# 70     Rafael Nadal                      Barcelona          Barcelona, Spain
# 71     Rafael Nadal  ATP Masters 1000 Indian Wells  Indian Wells, CA, U.S.A.
# 72     Rafael Nadal                Australian Open      Melbourne, Australia
# 73     Rafael Nadal                        US Open      New York, NY, U.S.A.
# 74     Rafael Nadal      ATP Masters 1000 Shanghai           Shanghai, China
# ...             ...                            ...                       ...
# 56768  Rafael Nadal                      Stuttgart        Stuttgart, Germany
# 56782  Rafael Nadal                       Spain F5           Alicante, Spain
# 56783  Rafael Nadal   ATP Masters 1000 Monte Carlo       Monte Carlo, Monaco
# 56784  Rafael Nadal                        Hamburg          Hamburg, Germany
# 56788  Rafael Nadal                         Bastad            Bastad, Sweden
#
#                           Date  Ground     GameRound GameRank  \
# 70     2019.04.22 - 2019.04.28    Clay   Round of 16      155
# 71     2019.03.04 - 2019.03.17    Hard   Round of 64      192
# 72     2019.01.14 - 2019.01.27    Hard   Round of 16       57
# 73     2018.08.27 - 2018.09.09    Hard  Round of 128      148
# 74     2017.10.09 - 2017.10.15    Hard   Round of 32       56
# ...                        ...     ...           ...      ...
# 56768  2003.07.14 - 2003.07.20    Clay   Round of 64      317
# 56782  2002.07.08 - 2002.07.14    Clay   Semi-Finals      334
# 56783  2003.04.14 - 2003.04.20    Clay   Round of 64       49
# 56784  2003.01.27 - 2003.02.02  Carpet   Semi-Finals      142
# 56788  2003.07.07 - 2003.07.13    Clay   Round of 16       83
#
#                   Oponent WL        Score  ... Sets  Start_Date   End_Date  \
# 70           David Ferrer  W        63 63  ...    2  2019-04-22 2019-04-28
# 71        Jared Donaldson  W        61 61  ...    2  2019-03-04 2019-03-17
# 72          Tomas Berdych  W     60 61 76  ...    3  2019-01-14 2019-01-27
# 73           David Ferrer  W  63 34 (RET)  ...    2  2018-08-27 2018-09-09
# 74        Jared Donaldson  W        62 61  ...    2  2017-10-09 2017-10-15
# ...                   ... ..          ...  ...  ...         ...        ...
# 56768  Philipp Petzschner  W        75 61  ...    2  2003-07-14 2003-07-20
# 56782     Oscar Hernandez  W        62 64  ...    2  2002-07-08 2002-07-14
# 56783        Karol Kucera  W        61 62  ...    2  2003-04-14 2003-04-20
# 56784    Andrei Stoliarov  W        64 76  ...    2  2003-01-27 2003-02-02
# 56788       Albert Portas  W        60 64  ...    2  2003-07-07 2003-07-13
#
#        Year  PlayerName_RecentPerformance  Oponent_RecentPerformance  \
# 70     2019                           2.0                        2.0
# 71     2019                           2.0                        2.0
# 72     2019                           2.0                        2.0
# 73     2018                           2.0                        2.0
# 74     2017                           2.0                        2.0
# ...     ...                           ...                        ...
# 56768  2003                           2.0                        2.0
# 56782  2002                           2.0                        2.0
# 56783  2003                           2.0                        2.0
# 56784  2003                           2.0                        2.0
# 56788  2003                           2.0                        2.0
#
#        PlayerName_RecentPerformance2  Oponent_RecentPerformance2  \
# 70                               3.0                         3.0
# 71                               3.0                         2.0
# 72                               3.0                         3.0
# 73                               3.0                         3.0
# 74                               3.0                         2.0
# ...                              ...                         ...
# 56768                            3.0                         2.0
# 56782                            3.0                         2.0
# 56783                            3.0                         3.0
# 56784                            3.0                         2.0
# 56788                            3.0                         2.0
#
#        PlayerName_LastTimePlayed  Oponent_LastTimePlayed
# 70                           0.0                    35.0
# 71                           0.0                     7.0
# 72                           0.0                    14.0
# 73                           1.0                    14.0
# 74                           0.0                    14.0
# ...                          ...                     ...
# 56768                        7.0                    14.0
# 56782                        0.0                    28.0
# 56783                        0.0                    28.0
# 56784                        0.0                     7.0
# 56788                        0.0                     7.0
#
# [1111 rows x 21 columns]

# %%
new_df.isna().sum()
# Out:
# PlayerName                           0
# Tournament                           0
# Location                             0
# Date                                 0
# Ground                              96
# GameRound                            0
# GameRank                             0
# Oponent                              6
# WL                                   0
# Score                                0
# Score_Sets                           0
# Sets                                 0
# Start_Date                           0
# End_Date                          7007
# Year                                 0
# PlayerName_RecentPerformance       414
# Oponent_RecentPerformance            6
# PlayerName_RecentPerformance2      414
# Oponent_RecentPerformance2           6
# PlayerName_LastTimePlayed         7280
# Oponent_LastTimePlayed           22349
# dtype: int64

# %%
new_df['PlayerName'] = new_df['PlayerName'].astype(str)
new_df['Oponent'] = new_df['Oponent'].astype(str)

new_df['Player_Oponent'] = new_df[['PlayerName', 'Oponent']].apply(lambda x: '_'.join(sorted(x)), axis=1)

new_df.sort_values('Start_Date', inplace=True)
grouped = new_df.groupby('Start_Date')
mean_sets = grouped['Sets'].transform(lambda x: x.iloc[:-1].mean())
mean_sets[grouped.cumcount(ascending=False) == 0] = 0
mean_sets = mean_sets.round().clip(2, 3)
new_df['H2H'] = mean_sets

new_df.drop('Player_Oponent', axis=1, inplace=True)

# %%
new_df['PlayerName'] = new_df['PlayerName'].astype(str)
new_df['Oponent'] = new_df['Oponent'].astype(str)
new_df['Player_Oponent'] = new_df[['PlayerName', 'Oponent']].apply(lambda x: '_'.join(sorted(x)), axis=1)

new_df.sort_values('Start_Date', inplace=True)
grouped = new_df.groupby('Start_Date')
median_sets = grouped['Sets'].transform(lambda x: x.iloc[:-1].median())
median_sets[grouped.cumcount(ascending=False) == 0] = 0
median_sets = median_sets.round().clip(2, 3)
new_df['H2H_Median'] = median_sets
new_df.drop('Player_Oponent', axis=1, inplace=True)

# %%
new_df['H2H'].value_counts()
# Out:
# 2.0    583155
# 3.0     68262
# Name: H2H, dtype: int64

# %%
new_df['H2H_Median'].value_counts()
# Out:
# 2.0    627561
# 3.0     23856
# Name: H2H_Median, dtype: int64

# %%
new_df.head(6)
# Out:
#            PlayerName            Tournament  \
# 44017    Peter Wright      US Championships
# 37047  Adli El Shafei             Wimbledon
# 37048  Adli El Shafei             Wimbledon
# 37046  Adli El Shafei  French Championships
# 37044  Adli El Shafei  French Championships
# 37045  Adli El Shafei  French Championships
#
#                                    Location                     Date Ground  \
# 44017  Newport, Rhode Island, United States  1914.08.24 - 1914.09.01  Grass
# 37047                 London, Great Britain  1946.06.24 - 1946.07.05  Grass
# 37048                 London, Great Britain  1946.06.24 - 1946.07.05  Grass
# 37046                         Paris, France  1946.07.15 - 1946.07.28   Clay
# 37044                         Paris, France  1948.05.17 - 1948.05.30   Clay
# 37045                         Paris, France  1948.05.17 - 1948.05.30   Clay
#
#           GameRound GameRank         Oponent WL           Score  ...  \
# 44017   Round of 64        -        E. Gould  W     60 75 36 60  ...
# 37047  Round of 128        -  George Godsell  W  36 57 63 64 63  ...
# 37048   Round of 64        -      R.W. Baker  W        63 62 62  ...
# 37046   Round of 64        -  Stanley Drobac  W        62 61 60  ...
# 37044   Round of 64        -   Subba Sawhney  W        62 86 61  ...
# 37045  Round of 128        -     Jean Hugron  W        61 62 61  ...
#
#         End_Date  Year PlayerName_RecentPerformance Oponent_RecentPerformance  \
# 44017 1914-09-01  1914                          2.0                       3.0
# 37047 1946-07-05  1946                          2.0                       3.0
# 37048 1946-07-05  1946                          2.0                       3.0
# 37046 1946-07-28  1946                          2.0                       3.0
# 37044 1948-05-30  1948                          2.0                       3.0
# 37045 1948-05-30  1948                          2.0                       3.0
#
#        PlayerName_RecentPerformance2  Oponent_RecentPerformance2  \
# 44017                            2.0                         3.0
# 37047                            2.0                         3.0
# 37048                            2.0                         3.0
# 37046                            2.0                         3.0
# 37044                            2.0                         3.0
# 37045                            2.0                         3.0
#
#        PlayerName_LastTimePlayed  Oponent_LastTimePlayed  H2H  H2H_Median
# 44017                        NaN                     NaN  2.0         2.0
# 37047                        1.0                     NaN  3.0         3.0
# 37048                        0.0                     NaN  2.0         2.0
# 37046                       21.0                     NaN  2.0         2.0
# 37044                        1.0                     NaN  3.0         3.0
# 37045                        0.0                     NaN  2.0         2.0
#
# [6 rows x 23 columns]

# %%
new_df.to_csv('df_grande_final.csv', index=False)
