# %% [markdown]
# # Filtragem do DF e Últimas Alterações

# %%
import os
os.getcwd( )

os.chdir('C:\\data')

# %%
import datetime
import numpy as np
import pandas as pd
import random
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns

## for plotting
import matplotlib.pyplot as plt
import seaborn as sns

## for machine learning
from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

## for statistical tests
import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm
 
## for explainer
from lime import lime_tabular
    
## plot style and warnings    
plt.style.use('ggplot')
from IPython.display import display # Allows the use of display() for DataFrames
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('df_final_intermedio.csv',sep=",")

# %%
df.columns
# Out:
# Index(['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer', 'Tournament',
#        'Date', 'Ground', 'Prize', 'GameRound', 'OponentRank', 'Oponent', 'WL',
#        'Score', 'Location', 'PlayerRank', 'OverviewLink', 'BornDate',
#        'OponentBornDate', 'Ranking_Diff', 'TournamentType', 'Score_Sets',
#        'Sets', 'Start_Date', 'End_Date', 'Age_Player', 'Age_Oponent',
#        'Age_Difference', 'Seasons', 'Seasons_Encoded', 'GameRound_Fases',
#        'GameRoundFases_Encoded', 'Age_Difference_Interval',
#        'Encoded_Age_Difference_Interval', 'Ranking_Difference_Interval',
#        'Encoded_Ranking_Difference_Interval', 'BornContinent',
#        'Height_Imputed', 'Oponent_Height', 'Height_Difference',
#        'Height_Difference_Interval', 'Encoded_Height_Difference_Interval',
#        'Tournament_Year', 'Conversion', 'Present_Prize', 'Tiebreak',
#        'Tournament_Encoded', 'PlayerName_RecentPerformance',
#        'Oponent_RecentPerformance', 'PlayerName_RecentPerformance2',
#        'Oponent_RecentPerformance2', 'PlayerName_LastTimePlayed',
#        'Oponent_LastTimePlayed', 'H2H', 'H2H_Median', 'TimeDifference',
#        'TimeDifference_Interval', 'TimeDifference_Interval_Encoded',
#        'PlayerName_RecentPerformance_Encoded',
#        'Oponent_RecentPerformance_Encoded', 'H2H_Encoded'],
#       dtype='object')

# %% [markdown]
# ## Varíavel TieBreak

# %%
df = df.drop('Tiebreak', axis=1)
df['FirstSet'] = df['Score'].str[:2]
df['TieBreak'] = df['FirstSet'].apply(lambda x: 1 if '7' in x else 0)
df['PointDiff'] = df['FirstSet'].astype(str).isin(['60', '61', '62', '06', '16', '26']).astype(int)

# %%
df.head(6)
# Out:
#        PlayerName    Born  Height                               Hand  \
# 0  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 1  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 2  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 3  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 4  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 5  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
#
#                                           LinkPlayer  \
# 0  https://www.atptour.com/en/players/novak-djoko...
# 1  https://www.atptour.com/en/players/novak-djoko...
# 2  https://www.atptour.com/en/players/novak-djoko...
# 3  https://www.atptour.com/en/players/novak-djoko...
# 4  https://www.atptour.com/en/players/novak-djoko...
# 5  https://www.atptour.com/en/players/novak-djoko...
#
#                   Tournament                     Date Ground    Prize  \
# 0                    Beijing  2015.10.05 - 2015.10.11   Hard  2700510
# 1  ATP Masters 1000 Shanghai  2014.10.06 - 2014.10.12   Hard  4195895
# 2                    Beijing  2014.09.29 - 2014.10.05   Hard  2500470
# 3  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 4  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 5                    Beijing  2012.10.01 - 2012.10.07   Hard  2205000
#
#         GameRound  ...  H2H_Median TimeDifference TimeDifference_Interval  \
# 0     Semi-Finals  ...         2.0           35.0                 [31,60]
# 1  Quarter-Finals  ...         2.0            7.0                  [0,14]
# 2          Finals  ...         2.0           20.0                 [15,30]
# 3  Quarter-Finals  ...         2.0            6.0                  [0,14]
# 4     Semi-Finals  ...         2.0            6.0                  [0,14]
# 5     Round of 16  ...         2.0            7.0                  [0,14]
#
#   TimeDifference_Interval_Encoded PlayerName_RecentPerformance_Encoded  \
# 0                               3                                    1
# 1                               1                                    1
# 2                               2                                    1
# 3                               1                                    1
# 4                               1                                    1
# 5                               1                                    1
#
#    Oponent_RecentPerformance_Encoded H2H_Encoded FirstSet TieBreak  PointDiff
# 0                                  1           0       62        0          1
# 1                                  1           0       64        0          0
# 2                                  1           0       60        0          1
# 3                                  1           0       63        0          0
# 4                                  1           0       63        0          0
# 5                                  1           0       61        0          1
#
# [6 rows x 63 columns]

# %% [markdown]
# ## Variável Prize

# %%
intervals = [
    (0, 20000),
    (20000,25000),
    (25000,50000),
    (50000, 100000),
    (100000, 1000000),
    (1000000, float('inf'))
]

# Assign each prize money value to its corresponding interval category
df['Prize_Intervals'] = pd.cut(df['Present_Prize'], bins=pd.IntervalIndex.from_tuples(intervals))

# Print the frequency counts for each interval
interval_counts = df['Prize_Intervals'].value_counts().sort_index()

# %%
print(interval_counts)
# Out:
# (0.0, 20000.0]           2737
# (20000.0, 25000.0]       1274
# (25000.0, 50000.0]       1813
# (50000.0, 100000.0]      2794
# (100000.0, 1000000.0]    2549
# (1000000.0, inf]         1479
# Name: Prize_Intervals, dtype: int64

# %%
df.head(6)
# Out:
#        PlayerName    Born  Height                               Hand  \
# 0  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 1  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 2  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 3  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 4  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 5  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
#
#                                           LinkPlayer  \
# 0  https://www.atptour.com/en/players/novak-djoko...
# 1  https://www.atptour.com/en/players/novak-djoko...
# 2  https://www.atptour.com/en/players/novak-djoko...
# 3  https://www.atptour.com/en/players/novak-djoko...
# 4  https://www.atptour.com/en/players/novak-djoko...
# 5  https://www.atptour.com/en/players/novak-djoko...
#
#                   Tournament                     Date Ground    Prize  \
# 0                    Beijing  2015.10.05 - 2015.10.11   Hard  2700510
# 1  ATP Masters 1000 Shanghai  2014.10.06 - 2014.10.12   Hard  4195895
# 2                    Beijing  2014.09.29 - 2014.10.05   Hard  2500470
# 3  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 4  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 5                    Beijing  2012.10.01 - 2012.10.07   Hard  2205000
#
#         GameRound  ...  TimeDifference TimeDifference_Interval  \
# 0     Semi-Finals  ...            35.0                 [31,60]
# 1  Quarter-Finals  ...             7.0                  [0,14]
# 2          Finals  ...            20.0                 [15,30]
# 3  Quarter-Finals  ...             6.0                  [0,14]
# 4     Semi-Finals  ...             6.0                  [0,14]
# 5     Round of 16  ...             7.0                  [0,14]
#
#   TimeDifference_Interval_Encoded PlayerName_RecentPerformance_Encoded  \
# 0                               3                                    1
# 1                               1                                    1
# 2                               2                                    1
# 3                               1                                    1
# 4                               1                                    1
# 5                               1                                    1
#
#   Oponent_RecentPerformance_Encoded  H2H_Encoded FirstSet TieBreak PointDiff  \
# 0                                 1            0       62        0         1
# 1                                 1            0       64        0         0
# 2                                 1            0       60        0         1
# 3                                 1            0       63        0         0
# 4                                 1            0       63        0         0
# 5                                 1            0       61        0         1
#
#     Prize_Intervals
# 0  (1000000.0, inf]
# 1  (1000000.0, inf]
# 2  (1000000.0, inf]
# 3  (1000000.0, inf]
# 4  (1000000.0, inf]
# 5  (1000000.0, inf]
#
# [6 rows x 64 columns]

# %%
encoder = LabelEncoder()
df["Prize_Intervals_Encoded"] = encoder.fit_transform(df["Prize_Intervals"])

# %%
df.head(6)
# Out:
#        PlayerName    Born  Height                               Hand  \
# 0  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 1  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 2  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 3  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 4  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
# 5  Novak Djokovic  Serbia   188.0  Right-Handed, Two-Handed Backhand
#
#                                           LinkPlayer  \
# 0  https://www.atptour.com/en/players/novak-djoko...
# 1  https://www.atptour.com/en/players/novak-djoko...
# 2  https://www.atptour.com/en/players/novak-djoko...
# 3  https://www.atptour.com/en/players/novak-djoko...
# 4  https://www.atptour.com/en/players/novak-djoko...
# 5  https://www.atptour.com/en/players/novak-djoko...
#
#                   Tournament                     Date Ground    Prize  \
# 0                    Beijing  2015.10.05 - 2015.10.11   Hard  2700510
# 1  ATP Masters 1000 Shanghai  2014.10.06 - 2014.10.12   Hard  4195895
# 2                    Beijing  2014.09.29 - 2014.10.05   Hard  2500470
# 3  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 4  ATP Masters 1000 Shanghai  2012.10.08 - 2012.10.14   Hard  3531600
# 5                    Beijing  2012.10.01 - 2012.10.07   Hard  2205000
#
#         GameRound  ...  TimeDifference_Interval  \
# 0     Semi-Finals  ...                  [31,60]
# 1  Quarter-Finals  ...                   [0,14]
# 2          Finals  ...                  [15,30]
# 3  Quarter-Finals  ...                   [0,14]
# 4     Semi-Finals  ...                   [0,14]
# 5     Round of 16  ...                   [0,14]
#
#   TimeDifference_Interval_Encoded PlayerName_RecentPerformance_Encoded  \
# 0                               3                                    1
# 1                               1                                    1
# 2                               2                                    1
# 3                               1                                    1
# 4                               1                                    1
# 5                               1                                    1
#
#   Oponent_RecentPerformance_Encoded H2H_Encoded  FirstSet TieBreak PointDiff  \
# 0                                 1           0        62        0         1
# 1                                 1           0        64        0         0
# 2                                 1           0        60        0         1
# 3                                 1           0        63        0         0
# 4                                 1           0        63        0         0
# 5                                 1           0        61        0         1
#
#     Prize_Intervals  Prize_Intervals_Encoded
# 0  (1000000.0, inf]                        5
# 1  (1000000.0, inf]                        5
# 2  (1000000.0, inf]                        5
# 3  (1000000.0, inf]                        5
# 4  (1000000.0, inf]                        5
# 5  (1000000.0, inf]                        5
#
# [6 rows x 65 columns]

# %%
df.columns
# Out:
# Index(['PlayerName', 'Born', 'Height', 'Hand', 'LinkPlayer', 'Tournament',
#        'Date', 'Ground', 'Prize', 'GameRound', 'OponentRank', 'Oponent', 'WL',
#        'Score', 'Location', 'PlayerRank', 'OverviewLink', 'BornDate',
#        'OponentBornDate', 'Ranking_Diff', 'TournamentType', 'Score_Sets',
#        'Sets', 'Start_Date', 'End_Date', 'Age_Player', 'Age_Oponent',
#        'Age_Difference', 'Seasons', 'Seasons_Encoded', 'GameRound_Fases',
#        'GameRoundFases_Encoded', 'Age_Difference_Interval',
#        'Encoded_Age_Difference_Interval', 'Ranking_Difference_Interval',
#        'Encoded_Ranking_Difference_Interval', 'BornContinent',
#        'Height_Imputed', 'Oponent_Height', 'Height_Difference',
#        'Height_Difference_Interval', 'Encoded_Height_Difference_Interval',
#        'Tournament_Year', 'Conversion', 'Present_Prize', 'Tournament_Encoded',
#        'PlayerName_RecentPerformance', 'Oponent_RecentPerformance',
#        'PlayerName_RecentPerformance2', 'Oponent_RecentPerformance2',
#        'PlayerName_LastTimePlayed', 'Oponent_LastTimePlayed', 'H2H',
#        'H2H_Median', 'TimeDifference', 'TimeDifference_Interval',
#        'TimeDifference_Interval_Encoded',
#        'PlayerName_RecentPerformance_Encoded',
#        'Oponent_RecentPerformance_Encoded', 'H2H_Encoded', 'FirstSet',
#        'TieBreak', 'PointDiff', 'Prize_Intervals', 'Prize_Intervals_Encoded'],
#       dtype='object')

# %% [markdown]
# ## Filtragem

# %%
selected_columns=["Sets","Seasons_Encoded","GameRoundFases_Encoded","Encoded_Age_Difference_Interval","Encoded_Ranking_Difference_Interval",
                 "Encoded_Height_Difference_Interval","TieBreak","Tournament_Encoded","PlayerName_RecentPerformance_Encoded","Oponent_RecentPerformance_Encoded",
                 "H2H_Encoded","TimeDifference_Interval_Encoded","Present_Prize",
                 "Prize_Intervals_Encoded","PointDiff","Age_Difference"]
df_final = df[selected_columns].copy()
df_final.to_csv('final.csv', index=False)

# %%
df_final.columns
# Out:
# Index(['Sets', 'Seasons_Encoded', 'GameRoundFases_Encoded',
#        'Encoded_Age_Difference_Interval',
#        'Encoded_Ranking_Difference_Interval',
#        'Encoded_Height_Difference_Interval', 'TieBreak', 'Tournament_Encoded',
#        'PlayerName_RecentPerformance_Encoded',
#        'Oponent_RecentPerformance_Encoded', 'H2H_Encoded',
#        'TimeDifference_Interval_Encoded', 'Present_Prize',
#        'Prize_Intervals_Encoded', 'PointDiff', 'Age_Difference'],
#       dtype='object')

# %% [markdown]
# ### Correlações

# %%
# Create a subset DataFrame with the columns you want to analyze
subset_df = df_final[["Sets", "Seasons_Encoded", "GameRoundFases_Encoded", "Encoded_Age_Difference_Interval",
               "Encoded_Ranking_Difference_Interval", "Encoded_Height_Difference_Interval",
               "TieBreak", "Tournament_Encoded","PlayerName_RecentPerformance_Encoded",
                     "Oponent_RecentPerformance_Encoded","H2H_Encoded",
                     "Prize_Intervals_Encoded","PointDiff"]]

# Calculate the Cramer's V values for each column pair
cramer_v_values = []
for i in range(len(subset_df.columns)):
    for j in range(i+1, len(subset_df.columns)):
        contingency_table = pd.crosstab(subset_df.iloc[:, i], subset_df.iloc[:, j])
        chi2, _, _, _ = chi2_contingency(contingency_table)
        n = contingency_table.sum().sum()
        phi = np.sqrt(chi2 / n)
        r, k = contingency_table.shape
        cramers_v = phi / np.sqrt(min(r - 1, k - 1))
        cramer_v_values.append((subset_df.columns[i], subset_df.columns[j], cramers_v))

# Create a DataFrame with the Cramer's V values
cramer_v_df = pd.DataFrame(cramer_v_values, columns=["Column1", "Column2", "Cramer's V"])

# Create a pivot table for the heatmap
heatmap_data = cramer_v_df.pivot("Column1", "Column2", "Cramer's V")

# Move "Sets" to the first row of the heatmap
heatmap_data = heatmap_data.reindex(["Sets"] + list(heatmap_data.index[:-1]))

# Plot the Cramer's V heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Cramer's V Heatmap")
plt.show()

# %%
subset_df = df[["Sets", "Age_Difference", "Present_Prize"]]

# Calculate the correlations
correlation_matrix = subset_df.corr()

# Move "Sets" to the first row of the correlation matrix
sets_corr = correlation_matrix["Sets"].copy()
correlation_matrix = correlation_matrix.drop("Sets", axis=0)
correlation_matrix = correlation_matrix.append(sets_corr)

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix")
plt.show()
